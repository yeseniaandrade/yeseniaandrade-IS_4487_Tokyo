# %% [markdown]
# # Day 2 Lab, IS 4487
#
# Outline
#
# - Loading installed packages
# - Inspect data
# - Clean data
# - Summarize data
# - Explore plot types

# %% [markdown]
# # Notebook Instructions
#
# Again, remember to save a copy of the notebook in Drive so that you can save your changes.
#
# When you are done revising this notebook save your changes to GitHub and upload the URL for the file to Canvas for the assignment.

# %% [markdown]
# # Wrangle the MegaTelco Data

# %% [markdown]
# ##Load Libraries
#
# Remember, we will be using:
# - Pandas
# - Scikitlearn
# - Matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Load the Data
#
# In this case we will load  the MegaTelCo data directly from the URL in GitHub.

# %%
mtc = pd.read_csv("https://raw.githubusercontent.com/jefftwebb/is_4487_base/dd870389117d5b24eee7417d5378d80496555130/Labs/DataSets/megatelco_leave_survey.csv")

# %% [markdown]
# Examine the data quickly for mistakes and to get a sense of the variables:

# %%
#look at the top rows
mtc.head(10)

# %%
#look at last rows
mtc.tail(10)

# %%
#get a summary of the dataset
mtc.describe()

# %%
#look at the datatypes
mtc.info()

# %% [markdown]
# Did you notice anything unusual about the amounts for `house`?  And what about `handset_price` and `income`? The data needs to be cleaned.

# %% [markdown]
# ## Data Cleaning
#
# To filter out rows with mistakes we will use square bracket notation introduced in the last lab.

# %% [markdown]
# Here is an example of how to create a filtered dataset.

# %%
# Use a boolean mask
mtc[(mtc["income"] > 0) & (mtc["handset_price"] < 1000)].describe()
# Out:
#               income      overage     leftover           house  handset_price  \
# count    4998.000000  4998.000000  4998.000000     4998.000000    4998.000000
# mean    79933.979192    85.104042    24.242697   493761.689676     387.567227
# std     41682.984144    85.634060    26.847596   254278.677014     213.593685
# min     20028.000000     0.000000     0.000000  -796132.000000     130.000000
# 25%     41593.000000     0.000000     0.000000   260624.750000     219.000000
# 50%     75041.500000    59.000000    15.000000   452087.500000     322.000000
# 75%    115497.000000   177.000000    42.000000   701612.250000     527.750000
# max    159938.000000   335.000000    89.000000  1000000.000000     899.000000
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                  4995.000000            4998.000000   4998.000000
# mean                      7.738539               5.957983  10035.801921
# std                       8.802175               4.388871   5814.494101
# min                       0.000000               1.000000      2.000000
# 25%                       1.000000               2.000000   4949.500000
# 50%                       4.000000               5.000000  10126.000000
# 75%                      14.000000               9.000000  15087.750000
# max                      29.000000              15.000000  20000.000000

# %% [markdown]
# Looks better: `income` is positive and the outlier in `handset_price` is gone. But there are still impossible values in `house`.

# %% [markdown]
# ## Your Turn: Create a cleaned dataset
#
# 1. Filter `mtc` based on 3 logical conditions.
# 2. Save the cleaned data in a new DataFrame, `mtc_clean`.
# 3. Summarize this new DataFrame to verify that your changes worked.

# %%
# Your code goes here
# Out:
#      college  income  overage  leftover   house  handset_price  \
# 0        one   23859       70         0  519105            154
# 1       zero   72466       67        16  271182            262
# 2       zero   30883       60         0  647281            211
# 3        one   44512        0        22  754958            232
# 4       zero   70535        0         0  653421            310
# ...      ...     ...      ...       ...     ...            ...
# 4995    zero   93699       26        56  385632            384
# 4996    zero   25806       67        87  691020            142
# 4997     one   97033      138        28  710559            311
# 4998    zero   91558      229        15  853464            379
# 4999     one  115943      200        42  173038            459
#
#       over_15mins_calls_per_month  average_call_duration  \
# 0                             5.0                      8
# 1                             5.0                      5
# 2                             3.0                      8
# 3                             0.0                      5
# 4                             0.0                     14
# ...                           ...                    ...
# 4995                          5.0                      1
# 4996                          4.0                      2
# 4997                         10.0                      2
# 4998                         27.0                      4
# 4999                         24.0                      2
#
#      reported_satisfaction reported_usage_level considering_change_of_plan  \
# 0                      low                  low                        yes
# 1                      low                  low                        yes
# 2                      low                  low                        yes
# 3                      low                  low                         no
# 4                      low                  low                        yes
# ...                    ...                  ...                        ...
# 4995                  high                  low                        yes
# 4996                  high                  low                         no
# 4997                   low                 high                        yes
# 4998                  high                  low                         no
# 4999                  high                 high                        yes
#
#       leave     id
# 0     LEAVE   8183
# 1     LEAVE  12501
# 2      STAY   7425
# 3     LEAVE  13488
# 4      STAY  11389
# ...     ...    ...
# 4995  LEAVE  19270
# 4996   STAY  14549
# 4997   STAY   9972
# 4998   STAY  12685
# 4999  LEAVE  13561
#
# [4997 rows x 13 columns]

# %% [markdown]
# # Summarize the Data
#  What is average value of `house` at the two levels of `leave`?  (We call this a conditional mean because it is *conditional* on the value of `leave`.)

# %%
mtc_clean[['house','leave']].groupby('leave').mean().round(2)
# Out:
#            house
# leave
# LEAVE  439255.26
# STAY   547591.97

# %% [markdown]
#  Conclusion?  Stayers have substantially more expensive homes.

# %% [markdown]
# ## Your Turn: Calculate Additional Stats
#
# 1. Calculate means conditional on leave for `income` and `overage`.
# 2. Calculate *median* income for leavers and stayers. (Hint:  use the Gemini AI tool to figure out what function will calculate a median.)

# %%
# Your code goes here
# Out:
#   college  income  overage  leftover   house  handset_price  \
# 0     one   23859       70         0  519105            154
# 1    zero   72466       67        16  271182            262
# 2    zero   30883       60         0  647281            211
# 3     one   44512        0        22  754958            232
# 4    zero   70535        0         0  653421            310
#
#    over_15mins_calls_per_month  average_call_duration reported_satisfaction  \
# 0                          5.0                      8                   low
# 1                          5.0                      5                   low
# 2                          3.0                      8                   low
# 3                          0.0                      5                   low
# 4                          0.0                     14                   low
#
#   reported_usage_level considering_change_of_plan  leave     id
# 0                  low                        yes  LEAVE   8183
# 1                  low                        yes  LEAVE  12501
# 2                  low                        yes   STAY   7425
# 3                  low                         no  LEAVE  13488
# 4                  low                        yes   STAY  11389

# %% [markdown]
# # Practice
#
# - Create three plots to summarize and trend of relationships in the `MegaTelCo` data.

# %%
# Your code goes here

# %%
# Your code goes here

# %%
# Your code goes here
